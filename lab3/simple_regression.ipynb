# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("tvmarketing.csv")

df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
plt.xlabel('TV')
plt.ylabel('Sales')
plt.scatter( df[['TV']],df[['Sales']], color='red')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Assuming the last column is the target variable
X = df[['TV']]  # Features (all columns except the last one)
y = df[['Sales']]   # Target (last column)

# Split the dataset (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(df.shape)

# Print the first few rows of the training data
print(X_train.head())

# Print the first few rows of the testing data
print(X_test.head())
# Out:
# (200, 2)
#         TV
# 169  284.3
# 97   184.9
# 31   112.9
# 12    23.8
# 35   290.7
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3

# %%
# Visualize the training data
# plt.figure(figsize=(10,6))
plt.scatter(X_train, y_train, color='red')

# Plot the regression line

plt.plot(X_train, model.predict(X_train), color='blue')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')

# %%
# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Squared Error: 8.970991242413614
# R-squared Score: 0.6714477229302764

# %%
# Make predictions on the test set
print(X_test)
y_pred = model.predict(X_test)
# Out:
#         TV
# 95   163.3
# 15   195.4
# 30   292.9
# 158   11.7
# 128  220.3
# 115   75.1
# 69   216.8
# 170   50.0
# 174  222.4
# 45   175.1
# 66    31.5
# 182   56.2
# 165  234.5
# 78     5.4
# 186  139.5
# 177  170.2
# 56     7.3
# 152  197.6
# 82    75.3
# 68   237.4
# 124  229.5
# 16    67.8
# 148   38.0
# 93   250.9
# 65    69.0
# 60    53.5
# 84   213.5
# 67   139.3
# 125   87.2
# 132    8.4
# 9    199.8
# 18    69.2
# 55   198.9
# 75    16.9
# 150  280.7
# 104  238.2
# 135   48.3
# 137  273.7
# 164  117.2
# 76    27.5
# 79   116.0
# 197  177.0
# 38    43.1
# 24    62.3
# 122  224.0
# 195   38.2
# 29    70.6
# 19   147.3
# 143  104.6
# 86    76.3
# 114   78.2
# 173  168.4
# 5      8.7
# 126    7.8
# 117   76.4
# 73   129.4
# 140   73.4
# 98   289.7
# 172   19.6
# 96   197.6

# %%
# Compare actual vs predicted values
results = pd.DataFrame({'Actual': y_test.values, 'Predicted': y_pred})
print(results.head())  # Show first few rows
# Out:
#    Actual  Predicted
# 0    16.9  14.817854
# 1    22.4  16.307544
# 2    21.4  20.832305
# 3     7.3   7.782431
# 4    24.7  17.463099

# %%
# Evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"R-squared Score (R²): {r2:.4f}")
# Out:
# Model Evaluation:
# Mean Squared Error (MSE): 8.9710
# R-squared Score (R²): 0.6714

# %%
actual = model.predict(df.iloc[0, 1].reshape(1, -1))
print(actual)

'''
iloc is a Pandas method for accessing DataFrame values by their integer position. For example, df.iloc[0, 1] retrieves the value at the first row and second column of df.

reshape is a NumPy method that changes the shape of an array without changing its data. When you use reshape(1, -1), it converts the array into a 2D array with one row and automatically calculates the number of columns (the -1 acts as a placeholder).

For example, if df.iloc[0, 1] returns a scalar value, wrapping it (or usually working with an array) and using reshape(1, -1) ensures that the prediction method (which expects a 2D array of shape [n_samples, n_features]) works correctly.
'''
# Out:
# [[8.26507226]]
# c:\Users\Panchakoti Sravan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# '\niloc is a Pandas method for accessing DataFrame values by their integer position. For example, df.iloc[0, 1] retrieves the value at the first row and second column of df.\n\nreshape is a NumPy method that changes the shape of an array without changing its data. When you use reshape(1, -1), it converts the array into a 2D array with one row and automatically calculates the number of columns (the -1 acts as a placeholder).\n\nFor example, if df.iloc[0, 1] returns a scalar value, wrapping it (or usually working with an array) and using reshape(1, -1) ensures that the prediction method (which expects a 2D array of shape [n_samples, n_features]) works correctly.\n'

# %%
print(df.iloc[0,1].reshape(1, -1))
# Out:
# [[22.1]]
